# %%
import pandas as pd

# %%
df = pd.read_csv("data/mocap/csv_new/mocca1.csv")
df_bias = pd.read_csv("data/mocap/csv_new/mocca1_bias.csv")
df_bias = df_bias.reindex(columns=df.columns)
bias = df.iloc[863] - df_bias.iloc[863]
df -= bias

# %%
df.to_csv("data/mocap/csv_new/mocca1.csv", index=False)
